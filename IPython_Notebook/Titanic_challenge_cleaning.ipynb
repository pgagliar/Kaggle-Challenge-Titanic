# %%
import pandas as pd
import re
import os
import numpy as np
import pandas as pd
import pylab as P

# %%
path=os.path.join('/Users/pierregagliardi/DossierTravail/Programmation/PythonPath','Kaggle_Titanic','Dataset','train.csv')
df = pd.read_csv(path, header=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
df.describe()

# %%
df.head()

# %%
df.Age.hist()

# %%
import numpy as np
import pandas as pd
import pylab as P
import re
import os

def retrieve_title(name):
    m = re.search(', ([A-Za-z ]+).', name)
    return m.group(1)

def numeric_title(title):
    titles={
        ('Ms','Mme', 'Mlle'):0,
        ('Capt', 'Don', 'Major', 'Sir'): 1,
        ('Dona', 'Lady', 'the Countess', 'Jonkheer'): 2,
        ('Col'):3,
        ('Dr'):4,
        ('Master'):5,
        ('Miss'):6,
        ('Mr'):7,
        ('Mrs'):8,
        ('Rev'):9
    }
    for (key,value) in titles.iteritems():
        if title in key:
            return value
            break

#Open up the csv file in to a Python object
path=os.path.join('/Users/pierregagliardi/DossierTravail/Programmation/PythonPath','Kaggle_Titanic','Dataset','train.csv')
df = pd.read_csv(path, header=0)

#Gender in numeric
df['Gender'] = df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)

#Add column of titles
df['Title']=df['Name'].map(retrieve_title)
 
#Complete missing age values
titles = df['Title'].unique()
df['AgeFill'] = df['Age']
df['FamilySize'] = df['SibSp'] + df['Parch']

for title in titles:
    print "Average age of persons with title %s:"%(title)
    print "%d\n"%(df[df['Title']==title]['Age'].mean())
    df.loc[ (df.Age.isnull()) & (df.Title == title),'AgeFill'] = df[df['Title']==title]['Age'].mean()

df.loc[ (df.Age.isnull()) & (df.Title == title),'AgeFill'] = df[df['Title']==title]['Age'].mean()
df['Embarked_numeric'] = df['Embarked'].map( {'C': 0, 'S': 1, 'Q':2} ).astype(int)
df['Title_numeric'] = df['Title'].map( numeric_title ).astype(int)
df.loc[:,'AgeFill']=(df['AgeFill']-df['AgeFill'].mean())/df['AgeFill'].std()
df.loc[:,'Fare']=(df['Fare']-df['Fare'].mean())/df['Fare'].std()

df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked','Title'], axis=1)
df.head()
# Out:
# Average age of persons with title Mr:
# 32
#
# Average age of persons with title Mrs:
# 35
#
# Average age of persons with title Miss:
# 21
#
# Average age of persons with title Master:
# 4
#
# Average age of persons with title Don:
# 40
#
# Average age of persons with title Rev:
# 43
#
# Average age of persons with title Dr:
# 42
#
# Average age of persons with title Mme:
# 24
#
# Average age of persons with title Ms:
# 28
#
# Average age of persons with title Major:
# 48
#
# Average age of persons with title Lady:
# 48
#
# Average age of persons with title Sir:
# 49
#
# Average age of persons with title Mlle:
# 24
#
# Average age of persons with title Col:
# 58
#
# Average age of persons with title Capt:
# 70
#
# Average age of persons with title the Countess:
# 33
#
# Average age of persons with title Jonkheer:
# 38
#    PassengerId  Survived  Pclass  Age  SibSp  Parch      Fare  Gender  \
# 0            1         0       3   22      1      0 -0.502163       1
# ...

# %%
df[df['Age'] > 60]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare  Gender  \
# 33            34         0       2  66.0      0      0 -0.436762       1
# 54            55         0       1  65.0      0      1  0.599174       1
# 96            97         0       1  71.0      0      0  0.049302       1
# 116          117         0       3  70.5      0      0 -0.492101       1
# 170          171         0       1  61.0      0      0  0.026076       1
# 252          253         0       1  62.0      0      0 -0.113782       1
# 275          276         1       1  63.0      1      0  0.920727       0
# 280          281         0       3  65.0      0      0 -0.492101       1
# 326          327         0       3  61.0      0      0 -0.522538       1
# 438          439         0       1  64.0      1      4  4.644393       1
# 456          457         0       1  65.0      0      0 -0.113782       1
# 483          484         1       3  63.0      0      0 -0.455125       0
# ...

# %%
df['Cabin'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-c1faff8ce1d1> in <module>()
# ----> 1 df['Cabin'].unique()
#
# /Users/pierregagliardi/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/pierregagliardi/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Users/pierregagliardi/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c1faff8ce1d1> in <module>()
# ----> 1 df['Cabin'].unique()
#
# /Users/pierregagliardi/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/pierregagliardi/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# /Users/pierregagliardi/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...
